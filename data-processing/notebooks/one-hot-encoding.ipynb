# %% [markdown]
# # One-hot Encoding
# ---
# It is basically transform (binarication) categorical variables, where wich category will be transformed in a column.

# %%
import pandas as pd

df = pd.read_csv('../datasets/hum-res.csv')
df.head()
# Out:
#           Employee Name  Employee Number State     Zip         DOB   Age  \
# 0            Brown, Mia     1.103024e+09    MA  1450.0  11/24/1985  32.0
# 1  LaRotonda, William       1.106027e+09    MA  1460.0   4/26/1984  33.0
# 2      Steans, Tyrone       1.302053e+09    MA  2703.0    9/1/1986  31.0
# 3       Howard, Estelle     1.211051e+09    MA  2170.0   9/16/1985  32.0
# 4           Singh, Nan      1.307060e+09    MA  2330.0   5/19/1988  29.0
#
#       Sex MaritalDesc CitizenDesc Hispanic/Latino  ... Date of Hire  \
# 0  Female     Married  US Citizen              No  ...   10/27/2008
# 1    Male    Divorced  US Citizen              No  ...     1/6/2014
# 2    Male      Single  US Citizen              No  ...    9/29/2014
# 3  Female     Married  US Citizen              No  ...    2/16/2015
# 4  Female      Single  US Citizen              No  ...     5/1/2015
#
#   Date of Termination       Reason For Term Employment Status     Department  \
# 0                 NaN  N/A - still employed            Active  Admin Offices
# 1                 NaN  N/A - still employed            Active  Admin Offices
# 2                 NaN  N/A - still employed            Active  Admin Offices
# 3           4/15/2015  N/A - still employed            Active  Admin Offices
# 4                 NaN  N/A - still employed            Active  Admin Offices
#
#                    Position Pay Rate        Manager Name  \
# 0              Accountant I    28.50  Brandon R. LeBlanc
# 1              Accountant I    23.00  Brandon R. LeBlanc
# 2              Accountant I    29.00  Brandon R. LeBlanc
# 3  Administrative Assistant    21.50  Brandon R. LeBlanc
# 4  Administrative Assistant    16.56  Brandon R. LeBlanc
#
#           Employee Source         Performance Score
# 0      Diversity Job Fair               Fully Meets
# 1      Website Banner Ads               Fully Meets
# 2         Internet Search               Fully Meets
# 3  Pay Per Click - Google  N/A- too early to review
# 4      Website Banner Ads  N/A- too early to review
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Transforming a category

# %%
# Unique values
df['MaritalDesc'].unique()
# Out:
# array(['Married', 'Divorced', 'Single', 'Separated', 'widowed', nan],
#       dtype=object)

# %%
dumm = pd.get_dummies(df['MaritalDesc'])
dumm
# Out:
#      Divorced  Married  Separated  Single  widowed
# 0           0        1          0       0        0
# 1           1        0          0       0        0
# 2           0        0          0       1        0
# 3           0        1          0       0        0
# 4           0        0          0       1        0
# ..        ...      ...        ...     ...      ...
# 297         0        1          0       0        0
# 298         0        0          0       1        0
# 299         0        0          0       1        0
# 300         0        0          0       1        0
# 301         0        0          0       0        0
#
# [302 rows x 5 columns]

# %% [markdown]
# ### Concating dummies data (one-hot encoded)

# %%
df_new = pd.concat([dumm, df], axis=1).drop(['MaritalDesc'], axis=1)
df_new.head()
# Out:
#    Divorced  Married  Separated  Single  widowed         Employee Name  \
# 0         0        1          0       0        0            Brown, Mia
# 1         1        0          0       0        0  LaRotonda, William
# 2         0        0          0       1        0      Steans, Tyrone
# 3         0        1          0       0        0       Howard, Estelle
# 4         0        0          0       1        0           Singh, Nan
#
#    Employee Number State     Zip         DOB  ...  Date of Hire  \
# 0     1.103024e+09    MA  1450.0  11/24/1985  ...    10/27/2008
# 1     1.106027e+09    MA  1460.0   4/26/1984  ...      1/6/2014
# 2     1.302053e+09    MA  2703.0    9/1/1986  ...     9/29/2014
# 3     1.211051e+09    MA  2170.0   9/16/1985  ...     2/16/2015
# 4     1.307060e+09    MA  2330.0   5/19/1988  ...      5/1/2015
#
#   Date of Termination       Reason For Term Employment Status     Department  \
# 0                 NaN  N/A - still employed            Active  Admin Offices
# 1                 NaN  N/A - still employed            Active  Admin Offices
# 2                 NaN  N/A - still employed            Active  Admin Offices
# 3           4/15/2015  N/A - still employed            Active  Admin Offices
# 4                 NaN  N/A - still employed            Active  Admin Offices
#
#                    Position Pay Rate        Manager Name  \
# 0              Accountant I    28.50  Brandon R. LeBlanc
# 1              Accountant I    23.00  Brandon R. LeBlanc
# 2              Accountant I    29.00  Brandon R. LeBlanc
# 3  Administrative Assistant    21.50  Brandon R. LeBlanc
# 4  Administrative Assistant    16.56  Brandon R. LeBlanc
#
#           Employee Source         Performance Score
# 0      Diversity Job Fair               Fully Meets
# 1      Website Banner Ads               Fully Meets
# 2         Internet Search               Fully Meets
# 3  Pay Per Click - Google  N/A- too early to review
# 4      Website Banner Ads  N/A- too early to review
#
# [5 rows x 25 columns]

# %%
def one_hot_encode(dataframe: pd.DataFrame, feature: str) -> pd.Series:
    dumm = pd.get_dummies(dataframe[feature])
    df_r = pd.concat([dumm, dataframe], axis=1)
    return df_r.drop([feature], axis=1)

# %%
df_new.columns
# Out:
# Index(['Divorced', 'Married', 'Separated', 'Single', 'widowed',
#        'Employee Name', 'Employee Number', 'State', 'Zip', 'DOB', 'Age', 'Sex',
#        'CitizenDesc', 'Hispanic/Latino', 'RaceDesc', 'Date of Hire',
#        'Date of Termination', 'Reason For Term', 'Employment Status',
#        'Department', 'Position', 'Pay Rate', 'Manager Name', 'Employee Source',
#        'Performance Score'],
#       dtype='object')

# %%
df_new = one_hot_encode(df_new, 'Sex')
df_new.columns
# Out:
# Index(['Female', 'Male', 'male', 'Divorced', 'Married', 'Separated', 'Single',
#        'widowed', 'Employee Name', 'Employee Number', 'State', 'Zip', 'DOB',
#        'Age', 'CitizenDesc', 'Hispanic/Latino', 'RaceDesc', 'Date of Hire',
#        'Date of Termination', 'Reason For Term', 'Employment Status',
#        'Department', 'Position', 'Pay Rate', 'Manager Name', 'Employee Source',
#        'Performance Score'],
#       dtype='object')

# %%
df_new.head()
# Out:
#    Female  Male  male  Divorced  Married  Separated  Single  widowed  \
# 0       1     0     0         0        1          0       0        0
# 1       0     1     0         1        0          0       0        0
# 2       0     1     0         0        0          0       1        0
# 3       1     0     0         0        1          0       0        0
# 4       1     0     0         0        0          0       1        0
#
#           Employee Name  Employee Number  ... Date of Hire  \
# 0            Brown, Mia     1.103024e+09  ...   10/27/2008
# 1  LaRotonda, William       1.106027e+09  ...     1/6/2014
# 2      Steans, Tyrone       1.302053e+09  ...    9/29/2014
# 3       Howard, Estelle     1.211051e+09  ...    2/16/2015
# 4           Singh, Nan      1.307060e+09  ...     5/1/2015
#
#    Date of Termination       Reason For Term  Employment Status  \
# 0                  NaN  N/A - still employed             Active
# 1                  NaN  N/A - still employed             Active
# 2                  NaN  N/A - still employed             Active
# 3            4/15/2015  N/A - still employed             Active
# 4                  NaN  N/A - still employed             Active
#
#       Department                  Position Pay Rate        Manager Name  \
# 0  Admin Offices              Accountant I    28.50  Brandon R. LeBlanc
# 1  Admin Offices              Accountant I    23.00  Brandon R. LeBlanc
# 2  Admin Offices              Accountant I    29.00  Brandon R. LeBlanc
# 3  Admin Offices  Administrative Assistant    21.50  Brandon R. LeBlanc
# 4  Admin Offices  Administrative Assistant    16.56  Brandon R. LeBlanc
#
#           Employee Source         Performance Score
# 0      Diversity Job Fair               Fully Meets
# 1      Website Banner Ads               Fully Meets
# 2         Internet Search               Fully Meets
# 3  Pay Per Click - Google  N/A- too early to review
# 4      Website Banner Ads  N/A- too early to review
#
# [5 rows x 27 columns]
